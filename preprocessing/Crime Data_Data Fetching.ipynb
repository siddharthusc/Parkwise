# %%
import pandas as pd
from sodapy import Socrata

# %%
# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.lacity.org,
#                  MyAppToken,
#                  username="user@example.com",
#                  password="AFakePassword")

client = Socrata("data.lacity.org",
                 "8JwvqNkTSYSyJhCJckySNhwx4")
socrata_raw = client.get("2nrs-mtv8", limit=700000)
# Convert to pandas DataFrame
df = pd.DataFrame.from_records(socrata_raw)

# %%
df.shape
# Out:
# (690454, 28)

# %%
df.dtypes
# Out:
# dr_no             object
# date_rptd         object
# date_occ          object
# time_occ          object
# area              object
# area_name         object
# rpt_dist_no       object
# part_1_2          object
# crm_cd            object
# crm_cd_desc       object
# mocodes           object
# vict_age          object
# vict_sex          object
# vict_descent      object
# premis_cd         object
# premis_desc       object
# weapon_used_cd    object
# weapon_desc       object
# status            object
# status_desc       object
# crm_cd_1          object
# location          object
# lat               object
# lon               object
# crm_cd_2          object
# cross_street      object
# crm_cd_3          object
# crm_cd_4          object
# dtype: object

# %%
df.tail(n=10)
# Out:
#             dr_no                date_rptd                 date_occ time_occ  \
# 690444  230406516  2023-03-19T00:00:00.000  2023-03-19T00:00:00.000     0122
# 690445  230405171  2023-02-05T00:00:00.000  2023-02-02T00:00:00.000     1830
# 690446  231405429  2023-02-05T00:00:00.000  2023-02-05T00:00:00.000     1250
# 690447  230806871  2023-03-03T00:00:00.000  2023-03-02T00:00:00.000     0620
# 690448  231104474  2023-01-12T00:00:00.000  2023-01-12T00:00:00.000     1240
# 690449  230804266  2023-01-08T00:00:00.000  2023-01-08T00:00:00.000     1030
# 690450  230109201  2023-03-23T00:00:00.000  2023-03-22T00:00:00.000     1830
# 690451  231604807  2023-01-27T00:00:00.000  2023-01-26T00:00:00.000     1800
# 690452  231606525  2023-03-22T00:00:00.000  2023-03-22T00:00:00.000     1000
# 690453  230906458  2023-03-05T00:00:00.000  2023-03-05T00:00:00.000     0900
#
#        area   area_name rpt_dist_no part_1_2 crm_cd  \
# 690444   04  Hollenbeck        0488        1    510
# 690445   04  Hollenbeck        0428        1    236
# 690446   14     Pacific        1444        1    341
# 690447   08     West LA        0889        2    354
# 690448   11   Northeast        1107        1    440
# 690449   08     West LA        0839        1    341
# 690450   01     Central        0111        1    440
# 690451   16    Foothill        1663        2    740
# 690452   16    Foothill        1602        1    230
# 690453   09    Van Nuys        0914        2    745
#
#                                               crm_cd_desc  ... status  \
# 690444                                   VEHICLE - STOLEN  ...     IC
# 690445              INTIMATE PARTNER - AGGRAVATED ASSAULT  ...     IC
# 690446  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...     IC
# 690447                                  THEFT OF IDENTITY  ...     IC
# 690448                 THEFT PLAIN - PETTY ($950 & UNDER)  ...     IC
# 690449  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...     IC
# 690450                 THEFT PLAIN - PETTY ($950 & UNDER)  ...     IC
# 690451  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# 690452     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 690453           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
#
#         status_desc crm_cd_1                                  location  \
# 690444  Invest Cont      510   3200    GARNET                       ST
# 690445  Invest Cont      236   3000    BUDAU                        AV
# 690446  Invest Cont      341   4300    LINCOLN                      BL
# 690447  Invest Cont      354   2000 S  HOLT                         AV
# 690448  Invest Cont      440   1000    MILWAUKEE                    AV
# 690449  Invest Cont      341  10200    SANTA MONICA                 BL
# 690450  Invest Cont      440    700 W  CESAR E CHAVEZ               AV
# 690451  Invest Cont      740  12500    BRANFORD                     ST
# 690452  Invest Cont      230  12800    FILMORE                      ST
# 690453  Invest Cont      745  14500    HARTLAND                     ST
#
#             lat        lon crm_cd_2 cross_street crm_cd_3 crm_cd_4
# 690444  34.0248  -118.2076      NaN          NaN      NaN      NaN
# 690445  34.0808  -118.1738      NaN          NaN      NaN      NaN
# 690446  33.9846  -118.4428      NaN          NaN      NaN      NaN
# 690447  34.0412  -118.3814      NaN          NaN      NaN      NaN
# 690448  34.1214  -118.1915      NaN          NaN      NaN      NaN
# 690449  34.0611  -118.4184      NaN          NaN      NaN      NaN
# 690450  34.0606  -118.2439      NaN          NaN      NaN      NaN
# 690451  34.2466  -118.4054      NaN          NaN      NaN      NaN
# 690452   34.279  -118.4116      NaN          NaN      NaN      NaN
# 690453  34.1951  -118.4487      NaN          NaN      NaN      NaN
#
# [10 rows x 28 columns]

# %%
# Save dataframe to CSV and work locally from this point
df.to_csv("crime_data_raw.csv", index=False, encoding='utf-8')
