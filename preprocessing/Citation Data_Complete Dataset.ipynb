# %%
import pandas as pd
import stateplane

# %%
# Read raw data locally
df = pd.read_csv("citation_data_raw.csv", low_memory=False)

# %%
display(df)
# Out:
#         ticket_number               issue_date  issue_time rp_state_plate  \
# 0          1127615064  2020-01-01T00:00:00.000      1220.0             CA
# 1          1127615031  2020-01-01T00:00:00.000      1155.0             CA
# 2          1127620675  2020-01-01T00:00:00.000      1015.0             CA
# 3          1127620130  2020-01-01T00:00:00.000      2352.0             CA
# 4          1127615075  2020-01-01T00:00:00.000      1230.0             CA
# ...               ...                      ...         ...            ...
# 5697626    4562911916  2023-03-27T00:00:00.000       727.0             CA
# 5697627    4564280361  2023-03-27T00:00:00.000       943.0             CA
# 5697628    4564689511  2023-03-27T00:00:00.000      1352.0             CA
# 5697629    4564713650  2023-03-27T00:00:00.000      2231.0             CA
# 5697630    4562444434  2023-03-27T00:00:00.000       134.0             CA
#
#          plate_expiry_date  make body_style color              location  \
# 0                 202010.0  VOLV         TC    BL   ALAMEDA ST/COLON ST
# 1                      NaN  GALT         TL    BL       1715 E DENNI ST
# 2                 202003.0  HOND         PA    WH  BERTH 79 PARKING LOT
# 3                 201906.0  FORD         PA    GY  MARINE AVE & HARRY B
# 4                      NaN  WABA         TL    WH    SANDISON ST/GAMBLE
# ...                    ...   ...        ...   ...                   ...
# 5697626           202310.0  NISS         PU    WT         3101 6TH ST W
# 5697627                0.0   NaN         PA   NaN      5700 HOOVER ST S
# 5697628           202307.0  TOYT         PA    WT     4575 WESTLAWN AVE
# 5697629               11.0  FORD         PA    WT     12815 HERRICK AVE
# 5697630           202311.0  TOYT         PA    SL       1901 BUTLER AVE
#
#          route  ...  fine_amount      latitude     longitude  \
# 0          M74  ...         93.0  9.999900e+04  9.999900e+04
# 1          M74  ...        250.0  6.488337e+06  1.744508e+06
# 2        00005  ...         68.0  9.999900e+04  9.999900e+04
# 3         2L27  ...         50.0  9.999900e+04  9.999900e+04
# 4          M74  ...        250.0  9.999900e+04  9.999900e+04
# ...        ...  ...          ...           ...           ...
# 5697626    NaN  ...          0.0  6.474310e+06  1.845688e+06
# 5697627    NaN  ...          0.0  6.474637e+06  1.819061e+06
# 5697628    NaN  ...          0.0           NaN           NaN
# 5697629    NaN  ...          0.0           NaN           NaN
# 5697630  0504R  ...          0.0  6.425998e+06  1.837524e+06
#
#                   agency_desc color_desc body_style_desc violation_code  \
# 0                      VALLEY       BLUE             NaN            NaN
# 1                      VALLEY       BLUE             NaN            NaN
# 2                      VALLEY        NaN   PASSENGER CAR            NaN
# 3                      VALLEY       GREY   PASSENGER CAR            NaN
# 4                      VALLEY        NaN             NaN            NaN
# ...                       ...        ...             ...            ...
# 5697626  54 - DOT - HOLLYWOOD      WHITE   PICK-UP TRUCK            NaN
# 5697627   55 - DOT - SOUTHERN        NaN   PASSENGER CAR            NaN
# 5697628    51 - DOT - WESTERN      WHITE   PASSENGER CAR            NaN
# 5697629     53 - DOT - VALLEY      WHITE   PASSENGER CAR            NaN
# 5697630    51 - DOT - WESTERN     SILVER   PASSENGER CAR            NaN
#
#         violation_description meter_id marked_time
# 0                         NaN      NaN         NaN
# 1                         NaN      NaN         NaN
# 2                         NaN      NaN         NaN
# 3                         NaN      NaN         NaN
# 4                         NaN      NaN         NaN
# ...                       ...      ...         ...
# 5697626                   NaN      NaN       800.0
# 5697627                   NaN      NaN         0.0
# 5697628                   NaN      NaN         0.0
# 5697629                   NaN      NaN         0.0
# 5697630                   NaN      NaN         0.0
#
# [5697631 rows x 21 columns]

# %% [markdown]
# # Preprocessing

# %%
# Check the number of missing values
df.isna().sum()
# Out:
# ticket_number                  0
# issue_date                     0
# issue_time                   684
# rp_state_plate              2762
# plate_expiry_date         370595
# make                       34776
# body_style                 10857
# color                      51358
# location                    5446
# route                    2156768
# agency                         1
# fine_amount                55967
# latitude                   76704
# longitude                  76704
# agency_desc                    1
# color_desc                182483
# body_style_desc            44243
# violation_code            303133
# violation_description     461134
# meter_id                 4714810
# marked_time              3043593
# dtype: int64

# %%
# Remove entires with missing issue time
df = df[df['issue_time'].notna()]
# Remove entries with missing latitude/longitude
df = df[df['latitude'].notna()]
# Remove entries with missing violation code
df = df[df['violation_code'].notna()]
# Remove latitude/longitude entries with 99999 value (invalid)
df = df[df['latitude'] != 99999]
df = df[df['longitude'] != -99999]

# %%
# Inspect data types
df.dtypes
# Out:
# ticket_number             object
# issue_date                object
# issue_time               float64
# rp_state_plate            object
# plate_expiry_date        float64
# make                      object
# body_style                object
# color                     object
# location                  object
# route                     object
# agency                   float64
# fine_amount              float64
# latitude                 float64
# longitude                float64
# agency_desc               object
# color_desc                object
# body_style_desc           object
# violation_code            object
# violation_description     object
# meter_id                  object
# marked_time              float64
# dtype: object

# %%
# Convert issue date columns to datetime
df['issue_date'] = df['issue_date'].apply(pd.to_datetime)
# Format issue time
df = df.astype({'issue_time': int})

# %% [markdown]
# Since the latitude/longitude (XY) is in US Feet coordinates according to the California State Plane Coordinate System - Zone 5 (https://www.conservation.ca.gov/cgs/rgm/state-plane-coordinate-system), we want to convert it to lat/long system by using `stateplane` with project description [here](https://pypi.org/project/stateplane/).

# %%
# %%time
lat = list()
long = list()
for index, row in df.iterrows():
    work_coor = stateplane.to_latlon(row['latitude'], row['longitude'], epsg='2229')
    lat.append(work_coor[0])
    long.append(work_coor[1])
# Out:
# Wall time: 10min

# %%
# Add lat/lon information to dataframe and remove the old coordinates
df['lat'] = lat
df['lon'] = long
df = df.drop(columns = ['latitude', 'longitude'])

# %%
display(df)
# Out:
#         ticket_number issue_date  issue_time rp_state_plate  \
# 15         4508182571 2020-01-01         228             CA
# 16         4508195565 2020-01-01         736             CA
# 23         1109775155 2020-01-01         100             CA
# 24         1110713262 2020-01-01        1830             CA
# 25         1110713273 2020-01-01        1900             CA
# ...               ...        ...         ...            ...
# 5697585    4563783313 2023-03-27        2131             CA
# 5697586    4564468904 2023-03-27        2051             CA
# 5697588    4563965055 2023-03-27        2227             CA
# 5697589    4564298384 2023-03-27        2123             CA
# 5697590    4564603212 2023-03-27        2115             CA
#
#          plate_expiry_date  make body_style color             location  route  \
# 15                     NaN  VOLK         PA    BK      1729 CLINTON ST  00600
# 16                     NaN  NISS         PA    GY        700 76TH ST W  00500
# 23                202002.0  DODG         PA    BL           328 LORENA    NaN
# 24                201909.0  NISS         PA    BK   2800 E OBSERVATORY    NaN
# 25                     NaN  FORD         PA    GY   2800 E OBSERVATORY    NaN
# ...                    ...   ...        ...   ...                  ...    ...
# 5697585           202302.0  VOLK         PA    WT         2118 6TH AVE  0205B
# 5697586                0.0  MERZ         PA    WT  3901 BLUE CANYON DR  350R1
# 5697588           202401.0  TOYT         PA    BK   15202 VICTORY BLVD    NaN
# 5697589           202004.0  NISS         VN    WT      600 PARK ROW DR    NaN
# 5697590           202304.0  CHEV         PA    SL      2331 KELTON AVE  0203A
#
#          ...  fine_amount          agency_desc color_desc body_style_desc  \
# 15       ...         68.0   56 - DOT - CENTRAL      BLACK   PASSENGER CAR
# 16       ...         68.0  55 - DOT - SOUTHERN       GREY   PASSENGER CAR
# 23       ...         68.0              WESTERN       BLUE   PASSENGER CAR
# 24       ...         68.0            HOLLYWOOD      BLACK   PASSENGER CAR
# 25       ...         68.0            HOLLYWOOD       GREY   PASSENGER CAR
# ...      ...          ...                  ...        ...             ...
# 5697585  ...         68.0   51 - DOT - WESTERN      WHITE   PASSENGER CAR
# 5697586  ...         68.0    53 - DOT - VALLEY      WHITE   PASSENGER CAR
# 5697588  ...         68.0    53 - DOT - VALLEY      BLACK   PASSENGER CAR
# 5697589  ...         73.0   56 - DOT - CENTRAL      WHITE             VAN
# 5697590  ...         68.0   51 - DOT - WESTERN     SILVER   PASSENGER CAR
#
#         violation_code violation_description meter_id marked_time        lat  \
# 15               80.61      STANDNG IN ALLEY      NaN         NaN  34.072180
# 16               22514          FIRE HYDRANT      NaN         NaN  33.970746
# 23              22500F                   NaN      NaN         NaN  34.034616
# 24               22514                   NaN      NaN         NaN  34.123408
# 25               22514                   NaN      NaN         NaN  34.123408
# ...                ...                   ...      ...         ...        ...
# 5697585         22500E     BLOCKING DRIVEWAY      NaN         0.0  34.037828
# 5697586         80.58L  PREFERENTIAL PARKING      NaN         0.0  34.138853
# 5697588          80.61      STANDNG IN ALLEY      NaN         0.0  34.186651
# 5697589         80.69B            NO PARKING      NaN         0.0  34.076598
# 5697590         80.58L  PREFERENTIAL PARKING      NaN         0.0  34.040672
#
#                 lon
# 15      -118.262252
# 16      -118.285640
# 23      -118.196633
# 24      -118.302409
# 25      -118.302409
# ...             ...
# 5697585 -118.323630
# 5697586 -118.385230
# 5697588 -118.464072
# 5697589 -118.231198
# 5697590 -118.431690
#
# [4993680 rows x 21 columns]

# %%
# Reset index
df.reset_index(drop=True, inplace=True)

# %%
# Save dataset
df.to_csv("citation_data_complete.csv", index=False, encoding='utf-8')
